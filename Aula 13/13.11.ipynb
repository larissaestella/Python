# %%
pip install pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting pandas
# ...
#                                               0.0/10.6 MB ? eta -:--:--
#      -                                        0.5/10.6 MB 14.5 MB/s eta 0:00:01
#      ----                                     1.2/10.6 MB 12.6 MB/s eta 0:00:01
#      ------                                   1.8/10.6 MB 12.3 MB/s eta 0:00:01
#      ------                                   1.8/10.6 MB 11.7 MB/s eta 0:00:01
#      ------                                   1.8/10.6 MB 11.7 MB/s eta 0:00:01
#      ------                                   1.8/10.6 MB 11.7 MB/s eta 0:00:01
#      ------                                   1.8/10.6 MB 11.7 MB/s eta 0:00:01
#      ------                                   1.8/10.6 MB 11.7 MB/s eta 0:00:01
#      ------                                   1.8/10.6 MB 11.7 MB/s eta 0:00:01
#      ------                                   1.8/10.6 MB 11.7 MB/s eta 0:00:01
# ...

# %%
import pandas as pd

# %%
data = {'coluna1': [10, 20, 30, 40, 50],
        'coluna2': [5, 10, 15, 20, 25],
        'coluna3': ['a', 'b', 'c', 'd', 'e'],
        'coluna4': ['x', 'y', 'z', 'w', 'v']}

df = pd.DataFrame(data)
df
# Out:
#    coluna1  coluna2 coluna3 coluna4
# 0       10        5       a       x
# 1       20       10       b       y
# 2       30       15       c       z
# 3       40       20       d       w
# 4       50       25       e       v

# %%
# Seleciona linha do índice

df.iloc[2]
# Out:
# coluna1    30
# coluna2    15
# coluna3     c
# coluna4     z
# Name: 2, dtype: object

# %%
def soma_coluna_numerica(coluna):
    return coluna.sum()

resultado_soma = soma_coluna_numerica(df['coluna1'])
resultado_soma

df
# Out:
#    coluna1  coluna2 coluna3 coluna4  soma
# 0       10        5       a       x    15
# 1       20       10       b       y    30
# 2       30       15       c       z    45
# 3       40       20       d       w    60
# 4       50       25       e       v    75

# %%
df['soma'] = df['coluna1'] + df['coluna2']
df
# Out:
#    coluna1  coluna2 coluna3 coluna4  soma
# 0       10        5       a       x    15
# 1       20       10       b       y    30
# 2       30       15       c       z    45
# 3       40       20       d       w    60
# 4       50       25       e       v    75

# %%
# Cálculo da soma entre duas colunas usando função def

def soma_coluna(df):
    df['soma'] = df['coluna1'] + df['coluna2']
    return df 

soma_coluna(df)
# Out:
#    coluna1  coluna2 coluna3 coluna4  soma
# 0       10        5       a       x    15
# 1       20       10       b       y    30
# 2       30       15       c       z    45
# 3       40       20       d       w    60
# 4       50       25       e       v    75

# %%
def operaçoes(df):
    if df['coluna3'] == 'a' or df['coluna3'] == 'c':
        return

# %%
# Usando função, calcule a soma entre a coluna 1 e 2 quando a coluna 3 for a ou c, calcule a subtração, quando a coluna 3 for b ou d, e faça a 
# multiplicação quando a coluna 3 for e 

def operaçoes(df):
    if df['coluna3'] == 'a' or df['coluna3'] == 'c':
        df['soma'] == df['coluna1'] + df['coluna2']

    elif df['coluna3'] == 'b' or df['coluna3'] == 'd':
        df['sub'] == df['coluna1'] - df['coluna2']

    elif df['coluna3'] == 'e':
        df['multiplicação'] == df['coluna1'] * df['coluna2']
        return df 

operaçoes(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10484\2935273592.py in ?()
#      11     elif df['coluna3'] == 'e':
#      12         df['multiplicação'] == df['coluna1'] * df['coluna2']
#      13         return df
#      14
# ---> 15 operaçoes(df)
#
# ~\AppData\Local\Temp\ipykernel_10484\2935273592.py in ?(df)
#       4 def operaçoes(df):
# ----> 5     if df['coluna3'] == 'a' or df['coluna3'] == 'c':
#       6         df['soma'] == df['coluna1'] + df['coluna2']
#       7
#       8     elif df['coluna3'] == 'b' or df['coluna3'] == 'd':
#
# c:\Python311\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1517     @final
#    1518     def __nonzero__(self) -> NoReturn:
# -> 1519         raise ValueError(
#    1520             f"The truth value of a {type(self).__name__} is ambiguous. "
# ...
